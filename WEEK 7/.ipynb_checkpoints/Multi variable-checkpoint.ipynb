# %% [markdown]
# ## Linear Regression
# #### Multivariant Linear Regression, from scratch.

# %% [markdown]
# #### AI Saturday Lagos Begineers Class (Instructors: `Tejumade Afonja`, `Kenechi Dukor`, `Stanley Dukor`, `Kelechi`)
# This exercise is adopted from [Andrew Ng Machine Learning Course](https://www.coursera.org/learn/machine-learning)

# %%
# Libraries required for this practice 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading Data

# %% [markdown]
# The data we will be using is a .txt file which contains a list of bedroom sizes, number of bedrooms and their corresponding price of the house.
#
# The values on the first column contains the bedroom sizes, the values of the second column contains the number of bedrooms and values on the third column contains the corresponding price of the house, in Naira.
#
# The goal of this exercise is to use linear regression and the optimization technique to generate a model that will predcit reasonable estimate of a house price when it is supplied the customers desired room size and number of rooms.

# %%
# Using pandas to view the data
data = pd.read_csv('data/ex1data2.txt', names=['size','bedroom','price'])
data.head() # this will show the first five data in the dataframe
# Out:
#    size  bedroom   price
# 0  2104        3  399900
# 1  1600        3  329900
# 2  2400        3  369000
# 3  1416        2  232000
# 4  3000        4  539900

# %%
# Lets convert values of the pandas dataframe into a numpy array
data = data.values

# %% [markdown]
# You can also convert the data in to a numpy array without needing to go through pandas. Use the code below
#
# `data = np.loadtxt("ex1data1.txt", delimiter=',')`

# %%
data.shape
# Out:
# (47, 3)

# %% [markdown]
# We have 47 training examples and two independent variable `x` on the first and second column and one dependent variable `y` on the third column
#
# **Recall:**
# - Our untrained model is given by: ![title](img/model.gif)
#
# - Which you can also be written as ![title](img/model2.gif)
#
# where:
# - `y` is the ground truth or output
# - `x` is the input values
# - `theta` is the weight or parameters that needs to learn

# %% [markdown]
# Beacuse we have three coefficient of `theta` `( x1, x2)`, we want to create a `97 x 2` matrix that contains the input values on the first column and second column.
#
# Notice that unlike in the last class, we did not create a third column here that contains `ones` which are coefficients for the **bias** `ie (theta0)`. This is because we would still have to normalize the input data. and it makes no sense normalizing `ones`, because we want them to remain as `ones`.

# %%
x_data = np.c_[data[:,0], data[:,1]]

# %%
# x_data

# %% [markdown]
# Similarly, we want to create a row vector with a dimension of `97 x 1` for all the output values in our dataset

# %%
y = np.c_[data[:,2]]
y.shape
# Out:
# (47, 1)

# %% [markdown]
# ### Data Visualization

# %%
# Lets plot the data to see how they correlate.
plt.scatter(x_data[:,0], y, s=32, marker='o')
plt.xlabel("Room Size")
plt.ylabel("Price")
plt.title("ROOM SIZE VS PRICE")
# Out:
# Text(0.5, 1.0, 'ROOM SIZE VS PRICE')

# %%
plt.scatter(x_data[:,1], y, s=32, marker='x')
plt.xlabel("Number of Bedroom")
plt.ylabel("Price")
plt.title("NUMBER OF ROOMS VS PRICE")
# Out:
# Text(0.5, 1.0, 'NUMBER OF ROOMS VS PRICE')

# %% [markdown]
# ### Class Discussion
#
# - What do you notice from the two plots?
# - Do you thing a reasonable model can be created?

# %% [markdown]
# ### Quick refresher
#
# Lets plot a 3D representation on the data for you to observe

# %%
from mpl_toolkits.mplot3d import axes3d, Axes3D #<-- Note the capitalization! 

# our input data

x1 = x_data[:,0]
x2 = x_data[:,1]

c = (x2<=0)
fig = plt.figure()
ax = Axes3D(fig) 

ax.scatter3D(x1, y, x2, c=c, cmap="coolwarm" );

# %% [markdown]
# **Class Discussion:** What do you understand from the plot?? lol

# %% [markdown]
# ## Feature Normalizing

# %% [markdown]
# Since the range of values of raw data varies widely, in some machine learning algorithms, objective functions will not work properly without normalization. ... Therefore, the range of all features should be normalized so that each feature contributes approximately proportionately to the final distance. [wiki](https://en.wikipedia.org/wiki/Feature_scaling)
# In this notebook, we will normalize our data using the formula below
# ![title](img/eqn1.gif)

# %%
def featureNorm(x_data):
    # save the feature data in another variable
    x_norm = x_data.copy()
    
    # Create a row vector of zeros, having the same number of rows as the input feature
    mean = np.mean(x_data, axis=0)
    standard_deviation = np.std(x_data, axis=0)
    print("... The mean and standard devation for the room sizes are: ", mean[0], " and ", standard_deviation[0] , "\n")
    print("... The mean and standard devation for the number of rooms are: ", mean[1], " and ", standard_deviation[1], "\n")
    
    # The formula
    x_norm = np.divide((x_data - mean),standard_deviation)
    print("... Input feature has been normalized", "\n")
    
    # Now, we can add the one vector that represent the coefficent of the bias that we discussed earlier
    x = np.concatenate((np.ones((x_data[:,0].size, 1)), x_norm), axis=1) 
    print("... A ones vector has been successfully concatenated to the input feature matrix", "\n")
    
    return x, mean, standard_deviation

# %%
x, mean, standard_deviation = featureNorm(x_data)
# Out:
# ... The mean and standard devation for the room sizes are:  2000.6808510638298  and  786.2026187430467
#
# ... The mean and standard devation for the number of rooms are:  3.1702127659574466  and  0.7528428090618782
#
# ... Input feature has been normalized
#
# ... A ones vector has been successfully concatenated to the input feature matrix

# %%
# x

# %% [markdown]
# ### Training

# %% [markdown]
# Recall from the class, the process to training a linear regression model is as follow.
#
# We want to find the appropriate value of `theta` that will give us a good estimate of a city's profit if lthe city's population is supplied.
#
# To do this,
# - We want to start with a random value of `theta` to generate a hypothesis
# ![title](img/model3.gif)
#
# - Then continually correct values of `theta` until the deviation of the hypothesis/prediction `h` from the ground-truth `y` is greatly reduced
#
# **Note:** In the last class, we used something like this `theta = [[0],[0],[0]]` to initialize the values of theta. Going forward, we will use the numpy function to initialize the values of theta, because we could have large number of theta values. ie `theta = np.zeros(3)`

# %%
def train(x, y):
    iteration = 1000
    # For this practice are initiallizing are theta with values of zero.
    theta = np.zeros((3, 1))
    
    # Here, want to save our cost function or loss or square error, 
    # so that we can have an idea of how the deviation of the hypothesis from the ground thruth reduces
    cost_function = np.zeros(iteration)
    
    for i in range(iteration):
        # Step 1: we make a prediction using the random weights (theta) that we initialized
        # @ is a fancy way do performing dot products
        h = x @ theta
        # Step 2: We take a step to correct the weights (theta) to that the next predicion will be better
        theta = update_weight(h, theta, x)
        # Step 3: We measure the deviation or error
        cost_function[i] = cost(x, theta)

        print("Running Gradient Descent. Current cost function is ", np.log(cost_function[i]))
        
    return theta, cost_function

# %% [markdown]
# But how do we check the error like we defined above?
#
# Remember the error formular (cost function)?
# ![title](img/model44.gif)
#
# where:
# - `m` is the number of training example
# - `x` is the input data
# - `h` is the hypothesis
# - `y` is the prediction
#
# The equation tries to find the square error between the ground truth and the prediction.

# %%
def cost(x, theta):
    m = x[:,0].size
    h = x @ theta
    return 0.5*np.sum(np.square(h - y))/m

# %% [markdown]
# Now that we are able to get a sense of the error, how do we update how weight (theta) such that is predicts better?
#
# Like we discussed in class, gradient descent algorithim will be used for this purpose.
#
# The general formular for gradient is given below:
# ![title](img/model6.gif)
# which can be differentiated to give:
# ![title](img/model5.gif)
# where
# - alpha is the learning rate
#
# ie: we continually update the weight(theta) by taking steps(alpha) for the derived gradient of the error until we have sufficiently minimized theta.

# %%
def update_weight(h, theta, x):
    m = x[:,0].size
    alpha = 0.01
    theta = theta - alpha * (1/m * (x.T @ (h - y)))
    return theta

# %% [markdown]
# Now, lets pass in our data and train.

# %%
theta, cost_values = train(x, y)
# Out:
# Running Gradient Descent. Current cost function is  24.886790883635804
# Running Gradient Descent. Current cost function is  24.86689279622735
# Running Gradient Descent. Current cost function is  24.847018611391245
# Running Gradient Descent. Current cost function is  24.827168522788295
# Running Gradient Descent. Current cost function is  24.807342728925
# Running Gradient Descent. Current cost function is  24.787541433199596
# Running Gradient Descent. Current cost function is  24.767764843947987
# Running Gradient Descent. Current cost function is  24.748013174489433
# Running Gradient Descent. Current cost function is  24.72828664317207
# Running Gradient Descent. Current cost function is  24.70858547341813
# Running Gradient Descent. Current cost function is  24.688909893768905
# Running Gradient Descent. Current cost function is  24.66926013792937
# Running Gradient Descent. Current cost function is  24.64963644481242
# Running Gradient Descent. Current cost function is  24.63003905858274
# Running Gradient Descent. Current cost function is  24.61046822870018
# Running Gradient Descent. Current cost function is  24.590924209962704
# Running Gradient Descent. Current cost function is  24.57140726254872
# Running Gradient Descent. Current cost function is  24.551917652058894
# Running Gradient Descent. Current cost function is  24.532455649557313
# Running Gradient Descent. Current cost function is  24.513021531611958
# Running Gradient Descent. Current cost function is  24.493615580334453
# Running Gradient Descent. Current cost function is  24.474238083419035
# Running Gradient Descent. Current cost function is  24.45488933418069
# Running Gradient Descent. Current cost function is  24.435569631592376
# Running Gradient Descent. Current cost function is  24.4162792803213
# Running Gradient Descent. Current cost function is  24.39701859076419
# Running Gradient Descent. Current cost function is  24.377787879081495
# Running Gradient Descent. Current cost function is  24.35858746723043
# Running Gradient Descent. Current cost function is  24.339417682996828
# Running Gradient Descent. Current cost function is  24.320278860025727
# Running Gradient Descent. Current cost function is  24.30117133785062
# Running Gradient Descent. Current cost function is  24.28209546192127
# Running Gradient Descent. Current cost function is  24.263051583630087
# Running Gradient Descent. Current cost function is  24.244040060336904
# Running Gradient Descent. Current cost function is  24.22506125539217
# Running Gradient Descent. Current cost function is  24.20611553815838
# Running Gradient Descent. Current cost function is  24.18720328402977
# Running Gradient Descent. Current cost function is  24.16832487445011
# Running Gradient Descent. Current cost function is  24.149480696928556
# Running Gradient Descent. Current cost function is  24.130671145053462
# Running Gradient Descent. Current cost function is  24.111896618504087
# Running Gradient Descent. Current cost function is  24.093157523060075
# Running Gradient Descent. Current cost function is  24.074454270608634
# Running Gradient Descent. Current cost function is  24.055787279149353
# Running Gradient Descent. Current cost function is  24.03715697279652
# Running Gradient Descent. Current cost function is  24.01856378177886
# Running Gradient Descent. Current cost function is  24.000008142436624
# Running Gradient Descent. Current cost function is  23.98149049721591
# Running Gradient Descent. Current cost function is  23.963011294660113
# Running Gradient Descent. Current cost function is  23.94457098939843
# Running Gradient Descent. Current cost function is  23.9261700421313
# Running Gradient Descent. Current cost function is  23.9078089196127
# Running Gradient Descent. Current cost function is  23.889488094629158
# Running Gradient Descent. Current cost function is  23.87120804597544
# Running Gradient Descent. Current cost function is  23.852969258426743
# Running Gradient Descent. Current cost function is  23.834772222707375
# Running Gradient Descent. Current cost function is  23.8166174354557
# Running Gradient Descent. Current cost function is  23.798505399185387
# Running Gradient Descent. Current cost function is  23.780436622242735
# Running Gradient Descent. Current cost function is  23.762411618760062
# Running Gradient Descent. Current cost function is  23.74443090860499
# Running Gradient Descent. Current cost function is  23.72649501732558
# Running Gradient Descent. Current cost function is  23.708604476091157
# Running Gradient Descent. Current cost function is  23.690759821628806
# Running Gradient Descent. Current cost function is  23.67296159615533
# Running Gradient Descent. Current cost function is  23.655210347304678
# Running Gradient Descent. Current cost function is  23.637506628050687
# Running Gradient Descent. Current cost function is  23.61985099662505
# Running Gradient Descent. Current cost function is  23.60224401643043
# Running Gradient Descent. Current cost function is  23.584686255948622
# Running Gradient Descent. Current cost function is  23.567178288643678
# Running Gradient Descent. Current cost function is  23.5497206928599
# Running Gradient Descent. Current cost function is  23.532314051714618
# Running Gradient Descent. Current cost function is  23.514958952985697
# Running Gradient Descent. Current cost function is  23.49765598899367
# Running Gradient Descent. Current cost function is  23.480405756478408
# Running Gradient Descent. Current cost function is  23.463208856470313
# Running Gradient Descent. Current cost function is  23.446065894155918
# Running Gradient Descent. Current cost function is  23.428977478737853
# Running Gradient Descent. Current cost function is  23.411944223289133
# Running Gradient Descent. Current cost function is  23.394966744601675
# Running Gradient Descent. Current cost function is  23.378045663029056
# Running Gradient Descent. Current cost function is  23.361181602323427
# Running Gradient Descent. Current cost function is  23.34437518946655
# Running Gradient Descent. Current cost function is  23.32762705449499
# Running Gradient Descent. Current cost function is  23.310937830319332
# Running Gradient Descent. Current cost function is  23.29430815253753
# Running Gradient Descent. Current cost function is  23.27773865924226
# Running Gradient Descent. Current cost function is  23.26122999082241
# Running Gradient Descent. Current cost function is  23.244782789758574
# Running Gradient Descent. Current cost function is  23.228397700412668
# Running Gradient Descent. Current cost function is  23.21207536881165
# Running Gradient Descent. Current cost function is  23.19581644242539
# Running Gradient Descent. Current cost function is  23.179621569938707
# Running Gradient Descent. Current cost function is  23.16349140101765
# Running Gradient Descent. Current cost function is  23.147426586070086
# Running Gradient Descent. Current cost function is  23.131427776000606
# Running Gradient Descent. Current cost function is  23.115495621959933
# Running Gradient Descent. Current cost function is  23.099630775088794
# Running Gradient Descent. Current cost function is  23.083833886256468
# Running Gradient Descent. Current cost function is  23.068105605794045
# Running Gradient Descent. Current cost function is  23.052446583222547
# Running Gradient Descent. Current cost function is  23.03685746697603
# Running Gradient Descent. Current cost function is  23.021338904119823
# Running Gradient Descent. Current cost function is  23.005891540064017
# Running Gradient Descent. Current cost function is  22.99051601827243
# Running Gradient Descent. Current cost function is  22.97521297996716
# Running Gradient Descent. Current cost function is  22.959983063828947
# Running Gradient Descent. Current cost function is  22.94482690569351
# Running Gradient Descent. Current cost function is  22.92974513824412
# Running Gradient Descent. Current cost function is  22.914738390700546
# Running Gradient Descent. Current cost function is  22.89980728850468
# Running Gradient Descent. Current cost function is  22.884952453003038
# Running Gradient Descent. Current cost function is  22.870174501126392
# Running Gradient Descent. Current cost function is  22.855474045066796
# Running Gradient Descent. Current cost function is  22.84085169195228
# Running Gradient Descent. Current cost function is  22.826308043519507
# Running Gradient Descent. Current cost function is  22.811843695784642
# Running Gradient Descent. Current cost function is  22.797459238712772
# Running Gradient Descent. Current cost function is  22.783155255886182
# Running Gradient Descent. Current cost function is  22.76893232417179
# Running Gradient Descent. Current cost function is  22.75479101338806
# Running Gradient Descent. Current cost function is  22.740731885971773
# Running Gradient Descent. Current cost function is  22.726755496644948
# Running Gradient Descent. Current cost function is  22.712862392082286
# Running Gradient Descent. Current cost function is  22.699053110579506
# Running Gradient Descent. Current cost function is  22.685328181722884
# Running Gradient Descent. Current cost function is  22.671688126060456
# Running Gradient Descent. Current cost function is  22.65813345477514
# Running Gradient Descent. Current cost function is  22.64466466936026
# Running Gradient Descent. Current cost function is  22.631282261297784
# Running Gradient Descent. Current cost function is  22.61798671173969
# Running Gradient Descent. Current cost function is  22.60477849119284
# Running Gradient Descent. Current cost function is  22.59165805920775
# Running Gradient Descent. Current cost function is  22.578625864071636
# Running Gradient Descent. Current cost function is  22.56568234250613
# Running Gradient Descent. Current cost function is  22.552827919370053
# Running Gradient Descent. Current cost function is  22.54006300736764
# Running Gradient Descent. Current cost function is  22.52738800676258
# Running Gradient Descent. Current cost function is  22.51480330509825
# Running Gradient Descent. Current cost function is  22.502309276924567
# Running Gradient Descent. Current cost function is  22.489906283531727
# Running Gradient Descent. Current cost function is  22.47759467269134
# Running Gradient Descent. Current cost function is  22.465374778405156
# Running Gradient Descent. Current cost function is  22.453246920661883
# Running Gradient Descent. Current cost function is  22.441211405202328
# Running Gradient Descent. Current cost function is  22.42926852329326
# Running Gradient Descent. Current cost function is  22.41741855151029
# Running Gradient Descent. Current cost function is  22.405661751530083
# Running Gradient Descent. Current cost function is  22.393998369932213
# Running Gradient Descent. Current cost function is  22.38242863801095
# Running Gradient Descent. Current cost function is  22.370952771597246
# Running Gradient Descent. Current cost function is  22.359570970891173
# Running Gradient Descent. Current cost function is  22.34828342030512
# Running Gradient Descent. Current cost function is  22.33709028831787
# Running Gradient Descent. Current cost function is  22.325991727339925
# Running Gradient Descent. Current cost function is  22.31498787359012
# Running Gradient Descent. Current cost function is  22.304078846983863
# Running Gradient Descent. Current cost function is  22.293264751033053
# Running Gradient Descent. Current cost function is  22.282545672757877
# Running Gradient Descent. Current cost function is  22.271921682610646
# Running Gradient Descent. Current cost function is  22.26139283441171
# Running Gradient Descent. Current cost function is  22.250959165297623
# Running Gradient Descent. Current cost function is  22.240620695681606
# Running Gradient Descent. Current cost function is  22.230377429226326
# Running Gradient Descent. Current cost function is  22.220229352829133
# Running Gradient Descent. Current cost function is  22.21017643661964
# Running Gradient Descent. Current cost function is  22.200218633969783
# Running Gradient Descent. Current cost function is  22.190355881516233
# Running Gradient Descent. Current cost function is  22.180588099195187
# Running Gradient Descent. Current cost function is  22.170915190289453
# Running Gradient Descent. Current cost function is  22.161337041487766
# Running Gradient Descent. Current cost function is  22.15185352295623
# Running Gradient Descent. Current cost function is  22.142464488421776
# Running Gradient Descent. Current cost function is  22.13316977526751
# Running Gradient Descent. Current cost function is  22.123969204639796
# Running Gradient Descent. Current cost function is  22.11486258156689
# Running Gradient Descent. Current cost function is  22.10584969508899
# Running Gradient Descent. Current cost function is  22.096930318399437
# Running Gradient Descent. Current cost function is  22.088104208996903
# Running Gradient Descent. Current cost function is  22.079371108848296
# Running Gradient Descent. Current cost function is  22.070730744562155
# Running Gradient Descent. Current cost function is  22.062182827572293
# Running Gradient Descent. Current cost function is  22.05372705433133
# Running Gradient Descent. Current cost function is  22.045363106513943
# Running Gradient Descent. Current cost function is  22.03709065122946
# Running Gradient Descent. Current cost function is  22.028909341243473
# Running Gradient Descent. Current cost function is  22.020818815208205
# Running Gradient Descent. Current cost function is  22.01281869790126
# Running Gradient Descent. Current cost function is  22.004908600472415
# Running Gradient Descent. Current cost function is  21.99708812069812
# Running Gradient Descent. Current cost function is  21.989356843243336
# Running Gradient Descent. Current cost function is  21.98171433993034
# Running Gradient Descent. Current cost function is  21.97416017001415
# Running Gradient Descent. Current cost function is  21.966693880464195
# Running Gradient Descent. Current cost function is  21.959315006251774
# Running Gradient Descent. Current cost function is  21.95202307064308
# Running Gradient Descent. Current cost function is  21.944817585497216
# Running Gradient Descent. Current cost function is  21.937698051568972
# Running Gradient Descent. Current cost function is  21.930663958815874
# Running Gradient Descent. Current cost function is  21.92371478670917
# Running Gradient Descent. Current cost function is  21.91685000454835
# Running Gradient Descent. Current cost function is  21.91006907177881
# Running Gradient Descent. Current cost function is  21.903371438312277
# Running Gradient Descent. Current cost function is  21.896756544849605
# Running Gradient Descent. Current cost function is  21.890223823205627
# Running Gradient Descent. Current cost function is  21.883772696635564
# Running Gradient Descent. Current cost function is  21.877402580162766
# Running Gradient Descent. Current cost function is  21.8711128809073
# Running Gradient Descent. Current cost function is  21.864902998415126
# Running Gradient Descent. Current cost function is  21.858772324987438
# Running Gradient Descent. Current cost function is  21.852720246009866
# Running Gradient Descent. Current cost function is  21.846746140281187
# Running Gradient Descent. Current cost function is  21.840849380341233
# Running Gradient Descent. Current cost function is  21.83502933279765
# Running Gradient Descent. Current cost function is  21.829285358651234
# Running Gradient Descent. Current cost function is  21.823616813619513
# Running Gradient Descent. Current cost function is  21.818023048458297
# Running Gradient Descent. Current cost function is  21.81250340928089
# Running Gradient Descent. Current cost function is  21.807057237874762
# Running Gradient Descent. Current cost function is  21.801683872015317
# Running Gradient Descent. Current cost function is  21.796382645776593
# Running Gradient Descent. Current cost function is  21.791152889838607
# Running Gradient Descent. Current cost function is  21.785993931791143
# Running Gradient Descent. Current cost function is  21.78090509643373
# Running Gradient Descent. Current cost function is  21.775885706071648
# Running Gradient Descent. Current cost function is  21.770935080807718
# Running Gradient Descent. Current cost function is  21.766052538829726
# Running Gradient Descent. Current cost function is  21.7612373966933
# Running Gradient Descent. Current cost function is  21.756488969600046
# Running Gradient Descent. Current cost function is  21.75180657167085
# Running Gradient Descent. Current cost function is  21.747189516214146
# Running Gradient Descent. Current cost function is  21.74263711598904
# Running Gradient Descent. Current cost function is  21.738148683463194
# Running Gradient Descent. Current cost function is  21.73372353106532
# Running Gradient Descent. Current cost function is  21.729360971432204
# Running Gradient Descent. Current cost function is  21.725060317650204
# Running Gradient Descent. Current cost function is  21.720820883491044
# Running Gradient Descent. Current cost function is  21.716641983641974
# Running Gradient Descent. Current cost function is  21.712522933930106
# Running Gradient Descent. Current cost function is  21.70846305154096
# Running Gradient Descent. Current cost function is  21.704461655231146
# Running Gradient Descent. Current cost function is  21.700518065535142
# Running Gradient Descent. Current cost function is  21.69663160496617
# Running Gradient Descent. Current cost function is  21.692801598211148
# Running Gradient Descent. Current cost function is  21.689027372319647
# Running Gradient Descent. Current cost function is  21.685308256886987
# Running Gradient Descent. Current cost function is  21.681643584231345
# Running Gradient Descent. Current cost function is  21.678032689564954
# Running Gradient Descent. Current cost function is  21.674474911159415
# Running Gradient Descent. Current cost function is  21.670969590505127
# Running Gradient Descent. Current cost function is  21.667516072464892
# Running Gradient Descent. Current cost function is  21.664113705421713
# Running Gradient Descent. Current cost function is  21.66076184142085
# Running Gradient Descent. Current cost function is  21.657459836306163
# Running Gradient Descent. Current cost function is  21.65420704985083
# Running Gradient Descent. Current cost function is  21.651002845882456
# Running Gradient Descent. Current cost function is  21.647846592402704
# Running Gradient Descent. Current cost function is  21.644737661701416
# Running Gradient Descent. Current cost function is  21.641675430465426
# Running Gradient Descent. Current cost function is  21.63865927988202
# Running Gradient Descent. Current cost function is  21.63568859573721
# Running Gradient Descent. Current cost function is  21.632762768508858
# Running Gradient Descent. Current cost function is  21.629881193454754
# Running Gradient Descent. Current cost function is  21.627043270695737
# Running Gradient Descent. Current cost function is  21.624248405293944
# Running Gradient Descent. Current cost function is  21.62149600732628
# Running Gradient Descent. Current cost function is  21.618785491953215
# Running Gradient Descent. Current cost function is  21.616116279482995
# Running Gradient Descent. Current cost function is  21.613487795431357
# Running Gradient Descent. Current cost function is  21.61089947057689
# Running Gradient Descent. Current cost function is  21.60835074101205
# Running Gradient Descent. Current cost function is  21.60584104819007
# Running Gradient Descent. Current cost function is  21.603369838967723
# Running Gradient Descent. Current cost function is  21.600936565644137
# Running Gradient Descent. Current cost function is  21.598540685995737
# Running Gradient Descent. Current cost function is  21.59618166330739
# Running Gradient Descent. Current cost function is  21.593858966399903
# Running Gradient Descent. Current cost function is  21.591572069653953
# Running Gradient Descent. Current cost function is  21.58932045303054
# Running Gradient Descent. Current cost function is  21.58710360208808
# Running Gradient Descent. Current cost function is  21.58492100799626
# Running Gradient Descent. Current cost function is  21.5827721675467
# Running Gradient Descent. Current cost function is  21.58065658316059
# Running Gradient Descent. Current cost function is  21.57857376289334
# Running Gradient Descent. Current cost function is  21.576523220436385
# Running Gradient Descent. Current cost function is  21.57450447511624
# Running Gradient Descent. Current cost function is  21.572517051890852
# Running Gradient Descent. Current cost function is  21.57056048134342
# Running Gradient Descent. Current cost function is  21.568634299673715
# Running Gradient Descent. Current cost function is  21.566738048687014
# Running Gradient Descent. Current cost function is  21.564871275780774
# Running Gradient Descent. Current cost function is  21.563033533929044
# Running Gradient Descent. Current cost function is  21.561224381664818
# Running Gradient Descent. Current cost function is  21.559443383060337
# Running Gradient Descent. Current cost function is  21.557690107705437
# Running Gradient Descent. Current cost function is  21.55596413068405
# Running Gradient Descent. Current cost function is  21.554265032548937
# Running Gradient Descent. Current cost function is  21.5525923992947
# Running Gradient Descent. Current cost function is  21.550945822329197
# Running Gradient Descent. Current cost function is  21.549324898443388
# Running Gradient Descent. Current cost function is  21.547729229779748
# Running Gradient Descent. Current cost function is  21.54615842379926
# Running Gradient Descent. Current cost function is  21.544612093247093
# Running Gradient Descent. Current cost function is  21.54308985611703
# Running Gradient Descent. Current cost function is  21.54159133561472
# Running Gradient Descent. Current cost function is  21.540116160119773
# Running Gradient Descent. Current cost function is  21.53866396314686
# Running Gradient Descent. Current cost function is  21.537234383305776
# Running Gradient Descent. Current cost function is  21.535827064260594
# Running Gradient Descent. Current cost function is  21.534441654687946
# Running Gradient Descent. Current cost function is  21.533077808234477
# Running Gradient Descent. Current cost function is  21.53173518347357
# Running Gradient Descent. Current cost function is  21.530413443861338
# Running Gradient Descent. Current cost function is  21.529112257691995
# Running Gradient Descent. Current cost function is  21.52783129805259
# Running Gradient Descent. Current cost function is  21.526570242777247
# Running Gradient Descent. Current cost function is  21.525328774400833
# Running Gradient Descent. Current cost function is  21.524106580112246
# Running Gradient Descent. Current cost function is  21.522903351707217
# Running Gradient Descent. Current cost function is  21.521718785540806
# Running Gradient Descent. Current cost function is  21.520552582479528
# Running Gradient Descent. Current cost function is  21.519404447853223
# Running Gradient Descent. Current cost function is  21.518274091406653
# Running Gradient Descent. Current cost function is  21.51716122725091
# Running Gradient Descent. Current cost function is  21.51606557381463
# Running Gradient Descent. Current cost function is  21.514986853795076
# Running Gradient Descent. Current cost function is  21.513924794109123
# Running Gradient Descent. Current cost function is  21.512879125844144
# Running Gradient Descent. Current cost function is  21.511849584208868
# Running Gradient Descent. Current cost function is  21.510835908484225
# Running Gradient Descent. Current cost function is  21.509837841974193
# Running Gradient Descent. Current cost function is  21.508855131956675
# Running Gradient Descent. Current cost function is  21.507887529634484
# Running Gradient Descent. Current cost function is  21.506934790086348
# Running Gradient Descent. Current cost function is  21.505996672218096
# Running Gradient Descent. Current cost function is  21.505072938713944
# Running Gradient Descent. Current cost function is  21.504163355987934
# Running Gradient Descent. Current cost function is  21.50326769413557
# Running Gradient Descent. Current cost function is  21.502385726885628
# Running Gradient Descent. Current cost function is  21.501517231552214
# Running Gradient Descent. Current cost function is  21.500661988987005
# Running Gradient Descent. Current cost function is  21.499819783531795
# Running Gradient Descent. Current cost function is  21.498990402971252
# Running Gradient Descent. Current cost function is  21.498173638485994
# Running Gradient Descent. Current cost function is  21.497369284605938
# Running Gradient Descent. Current cost function is  21.496577139163968
# Running Gradient Descent. Current cost function is  21.4957970032499
# Running Gradient Descent. Current cost function is  21.49502868116482
# Running Gradient Descent. Current cost function is  21.494271980375697
# Running Gradient Descent. Current cost function is  21.493526711470416
# Running Gradient Descent. Current cost function is  21.492792688113145
# Running Gradient Descent. Current cost function is  21.49206972700005
# Running Gradient Descent. Current cost function is  21.491357647815427
# Running Gradient Descent. Current cost function is  21.490656273188197
# Running Gradient Descent. Current cost function is  21.4899654286488
# Running Gradient Descent. Current cost function is  21.489284942586497
# Running Gradient Descent. Current cost function is  21.48861464620706
# Running Gradient Descent. Current cost function is  21.487954373490897
# Running Gradient Descent. Current cost function is  21.487303961151564
# Running Gradient Descent. Current cost function is  21.486663248594745
# Running Gradient Descent. Current cost function is  21.486032077877596
# Running Gradient Descent. Current cost function is  21.48541029366858
# Running Gradient Descent. Current cost function is  21.484797743207675
# Running Gradient Descent. Current cost function is  21.48419427626708
# Running Gradient Descent. Current cost function is  21.48359974511229
# Running Gradient Descent. Current cost function is  21.483014004463673
# Running Gradient Descent. Current cost function is  21.48243691145845
# Running Gradient Descent. Current cost function is  21.481868325613128
# Running Gradient Descent. Current cost function is  21.481308108786365
# Running Gradient Descent. Current cost function is  21.480756125142317
# Running Gradient Descent. Current cost function is  21.480212241114376
# Running Gradient Descent. Current cost function is  21.47967632536939
# Running Gradient Descent. Current cost function is  21.47914824877232
# Running Gradient Descent. Current cost function is  21.478627884351322
# Running Gradient Descent. Current cost function is  21.478115107263314
# Running Gradient Descent. Current cost function is  21.47760979475992
# Running Gradient Descent. Current cost function is  21.47711182615393
# Running Gradient Descent. Current cost function is  21.476621082786142
# Running Gradient Descent. Current cost function is  21.47613744799266
# Running Gradient Descent. Current cost function is  21.47566080707265
# Running Gradient Descent. Current cost function is  21.475191047256487
# Running Gradient Descent. Current cost function is  21.47472805767438
# Running Gradient Descent. Current cost function is  21.47427172932539
# Running Gradient Descent. Current cost function is  21.473821955046898
# Running Gradient Descent. Current cost function is  21.473378629484486
# Running Gradient Descent. Current cost function is  21.472941649062243
# Running Gradient Descent. Current cost function is  21.472510911953506
# Running Gradient Descent. Current cost function is  21.47208631805198
# Running Gradient Descent. Current cost function is  21.471667768943316
# Running Gradient Descent. Current cost function is  21.47125516787706
# Running Gradient Descent. Current cost function is  21.47084841973904
# Running Gradient Descent. Current cost function is  21.470447431024123
# Running Gradient Descent. Current cost function is  21.470052109809426
# Running Gradient Descent. Current cost function is  21.469662365727842
# Running Gradient Descent. Current cost function is  21.46927810994205
# Running Gradient Descent. Current cost function is  21.46889925511883
# Running Gradient Descent. Current cost function is  21.468525715403846
# Running Gradient Descent. Current cost function is  21.468157406396717
# Running Gradient Descent. Current cost function is  21.46779424512656
# Running Gradient Descent. Current cost function is  21.467436150027844
# Running Gradient Descent. Current cost function is  21.467083040916627
# Running Gradient Descent. Current cost function is  21.466734838967177
# Running Gradient Descent. Current cost function is  21.466391466688947
# Running Gradient Descent. Current cost function is  21.466052847903878
# Running Gradient Descent. Current cost function is  21.465718907724117
# Running Gradient Descent. Current cost function is  21.465389572530018
# Running Gradient Descent. Current cost function is  21.465064769948544
# Running Gradient Descent. Current cost function is  21.464744428831974
# Running Gradient Descent. Current cost function is  21.464428479236968
# Running Gradient Descent. Current cost function is  21.46411685240395
# Running Gradient Descent. Current cost function is  21.463809480736842
# Running Gradient Descent. Current cost function is  21.463506297783102
# Running Gradient Descent. Current cost function is  21.463207238214082
# Running Gradient Descent. Current cost function is  21.46291223780574
# Running Gradient Descent. Current cost function is  21.462621233419597
# Running Gradient Descent. Current cost function is  21.462334162984092
# Running Gradient Descent. Current cost function is  21.46205096547615
# Running Gradient Descent. Current cost function is  21.461771580903118
# Running Gradient Descent. Current cost function is  21.461495950284974
# Running Gradient Descent. Current cost function is  21.461224015636805
# Running Gradient Descent. Current cost function is  21.460955719951638
# Running Gradient Descent. Current cost function is  21.460691007183478
# Running Gradient Descent. Current cost function is  21.460429822230672
# Running Gradient Descent. Current cost function is  21.460172110919565
# Running Gradient Descent. Current cost function is  21.459917819988373
# Running Gradient Descent. Current cost function is  21.45966689707138
# Running Gradient Descent. Current cost function is  21.459419290683364
# Running Gradient Descent. Current cost function is  21.45917495020431
# Running Gradient Descent. Current cost function is  21.45893382586436
# Running Gradient Descent. Current cost function is  21.458695868729027
# Running Gradient Descent. Current cost function is  21.45846103068466
# Running Gradient Descent. Current cost function is  21.458229264424148
# Running Gradient Descent. Current cost function is  21.458000523432876
# Running Gradient Descent. Current cost function is  21.45777476197491
# Running Gradient Descent. Current cost function is  21.45755193507943
# Running Gradient Descent. Current cost function is  21.457331998527376
# Running Gradient Descent. Current cost function is  21.45711490883835
# Running Gradient Descent. Current cost function is  21.456900623257702
# Running Gradient Descent. Current cost function is  21.456689099743887
# Running Gradient Descent. Current cost function is  21.456480296955995
# Running Gradient Descent. Current cost function is  21.456274174241532
# Running Gradient Descent. Current cost function is  21.456070691624376
# Running Gradient Descent. Current cost function is  21.455869809792972
# Running Gradient Descent. Current cost function is  21.455671490088715
# Running Gradient Descent. Current cost function is  21.455475694494545
# Running Gradient Descent. Current cost function is  21.45528238562372
# Running Gradient Descent. Current cost function is  21.455091526708806
# Running Gradient Descent. Current cost function is  21.45490308159085
# Running Gradient Descent. Current cost function is  21.45471701470874
# Running Gradient Descent. Current cost function is  21.454533291088758
# Running Gradient Descent. Current cost function is  21.45435187633429
# Running Gradient Descent. Current cost function is  21.45417273661576
# Running Gradient Descent. Current cost function is  21.453995838660706
# Running Gradient Descent. Current cost function is  21.45382114974403
# Running Gradient Descent. Current cost function is  21.453648637678448
# Running Gradient Descent. Current cost function is  21.453478270805075
# Running Gradient Descent. Current cost function is  21.45331001798419
# Running Gradient Descent. Current cost function is  21.45314384858617
# Running Gradient Descent. Current cost function is  21.452979732482568
# Running Gradient Descent. Current cost function is  21.452817640037363
# Running Gradient Descent. Current cost function is  21.45265754209836
# Running Gradient Descent. Current cost function is  21.45249940998873
# Running Gradient Descent. Current cost function is  21.452343215498715
# Running Gradient Descent. Current cost function is  21.452188930877483
# Running Gradient Descent. Current cost function is  21.452036528825108
# Running Gradient Descent. Current cost function is  21.451885982484708
# Running Gradient Descent. Current cost function is  21.451737265434716
# Running Gradient Descent. Current cost function is  21.451590351681283
# Running Gradient Descent. Current cost function is  21.451445215650843
# Running Gradient Descent. Current cost function is  21.451301832182757
# Running Gradient Descent. Current cost function is  21.451160176522162
# Running Gradient Descent. Current cost function is  21.451020224312863
# Running Gradient Descent. Current cost function is  21.45088195159043
# Running Gradient Descent. Current cost function is  21.45074533477535
# Running Gradient Descent. Current cost function is  21.45061035066637
# Running Gradient Descent. Current cost function is  21.450476976433883
# Running Gradient Descent. Current cost function is  21.450345189613508
# Running Gradient Descent. Current cost function is  21.45021496809972
# Running Gradient Descent. Current cost function is  21.450086290139627
# Running Gradient Descent. Current cost function is  21.449959134326868
# Running Gradient Descent. Current cost function is  21.449833479595586
# Running Gradient Descent. Current cost function is  21.449709305214537
# Running Gradient Descent. Current cost function is  21.449586590781294
# Running Gradient Descent. Current cost function is  21.449465316216557
# Running Gradient Descent. Current cost function is  21.449345461758554
# Running Gradient Descent. Current cost function is  21.449227007957564
# Running Gradient Descent. Current cost function is  21.449109935670513
# Running Gradient Descent. Current cost function is  21.448994226055696
# Running Gradient Descent. Current cost function is  21.448879860567555
# Running Gradient Descent. Current cost function is  21.4487668209516
# Running Gradient Descent. Current cost function is  21.448655089239363
# Running Gradient Descent. Current cost function is  21.4485446477435
# Running Gradient Descent. Current cost function is  21.448435479052936
# Running Gradient Descent. Current cost function is  21.44832756602812
# Running Gradient Descent. Current cost function is  21.448220891796367
# Running Gradient Descent. Current cost function is  21.448115439747266
# Running Gradient Descent. Current cost function is  21.44801119352819
# Running Gradient Descent. Current cost function is  21.447908137039864
# Running Gradient Descent. Current cost function is  21.447806254432045
# Running Gradient Descent. Current cost function is  21.447705530099245
# Running Gradient Descent. Current cost function is  21.447605948676554
# Running Gradient Descent. Current cost function is  21.44750749503552
# Running Gradient Descent. Current cost function is  21.44741015428014
# Running Gradient Descent. Current cost function is  21.447313911742846
# Running Gradient Descent. Current cost function is  21.447218752980675
# Running Gradient Descent. Current cost function is  21.447124663771394
# Running Gradient Descent. Current cost function is  21.447031630109773
# Running Gradient Descent. Current cost function is  21.446939638203887
# Running Gradient Descent. Current cost function is  21.446848674471504
# Running Gradient Descent. Current cost function is  21.446758725536522
# Running Gradient Descent. Current cost function is  21.446669778225484
# Running Gradient Descent. Current cost function is  21.446581819564134
# Running Gradient Descent. Current cost function is  21.44649483677406
# Running Gradient Descent. Current cost function is  21.446408817269397
# Running Gradient Descent. Current cost function is  21.44632374865355
# Running Gradient Descent. Current cost function is  21.44623961871603
# Running Gradient Descent. Current cost function is  21.446156415429307
# Running Gradient Descent. Current cost function is  21.446074126945735
# Running Gradient Descent. Current cost function is  21.44599274159453
# Running Gradient Descent. Current cost function is  21.445912247878812
# Running Gradient Descent. Current cost function is  21.44583263447267
# Running Gradient Descent. Current cost function is  21.44575389021831
# Running Gradient Descent. Current cost function is  21.445676004123257
# Running Gradient Descent. Current cost function is  21.445598965357565
# Running Gradient Descent. Current cost function is  21.44552276325113
# Running Gradient Descent. Current cost function is  21.44544738729101
# Running Gradient Descent. Current cost function is  21.445372827118817
# Running Gradient Descent. Current cost function is  21.445299072528147
# Running Gradient Descent. Current cost function is  21.445226113462056
# Running Gradient Descent. Current cost function is  21.44515394001057
# Running Gradient Descent. Current cost function is  21.445082542408272
# Running Gradient Descent. Current cost function is  21.4450119110319
# Running Gradient Descent. Current cost function is  21.444942036397986
# Running Gradient Descent. Current cost function is  21.444872909160573
# Running Gradient Descent. Current cost function is  21.44480452010893
# Running Gradient Descent. Current cost function is  21.444736860165335
# Running Gradient Descent. Current cost function is  21.444669920382886
# Running Gradient Descent. Current cost function is  21.44460369194336
# Running Gradient Descent. Current cost function is  21.444538166155095
# Running Gradient Descent. Current cost function is  21.444473334450926
# Running Gradient Descent. Current cost function is  21.44440918838614
# Running Gradient Descent. Current cost function is  21.444345719636488
# Running Gradient Descent. Current cost function is  21.444282919996223
# Running Gradient Descent. Current cost function is  21.44422078137615
# Running Gradient Descent. Current cost function is  21.44415929580176
# Running Gradient Descent. Current cost function is  21.44409845541135
# Running Gradient Descent. Current cost function is  21.444038252454202
# Running Gradient Descent. Current cost function is  21.443978679288783
# Running Gradient Descent. Current cost function is  21.443919728380983
# Running Gradient Descent. Current cost function is  21.443861392302384
# Running Gradient Descent. Current cost function is  21.44380366372855
# Running Gradient Descent. Current cost function is  21.443746535437356
# Running Gradient Descent. Current cost function is  21.44369000030736
# Running Gradient Descent. Current cost function is  21.443634051316167
# Running Gradient Descent. Current cost function is  21.44357868153885
# Running Gradient Descent. Current cost function is  21.443523884146394
# Running Gradient Descent. Current cost function is  21.44346965240417
# Running Gradient Descent. Current cost function is  21.443415979670423
# Running Gradient Descent. Current cost function is  21.443362859394792
# Running Gradient Descent. Current cost function is  21.44331028511687
# Running Gradient Descent. Current cost function is  21.44325825046476
# Running Gradient Descent. Current cost function is  21.44320674915369
# Running Gradient Descent. Current cost function is  21.443155774984632
# Running Gradient Descent. Current cost function is  21.443105321842935
# Running Gradient Descent. Current cost function is  21.44305538369702
# Running Gradient Descent. Current cost function is  21.443005954597044
# Running Gradient Descent. Current cost function is  21.442957028673643
# Running Gradient Descent. Current cost function is  21.442908600136658
# Running Gradient Descent. Current cost function is  21.442860663273894
# Running Gradient Descent. Current cost function is  21.4428132124499
# Running Gradient Descent. Current cost function is  21.442766242104785
# Running Gradient Descent. Current cost function is  21.442719746753035
# Running Gradient Descent. Current cost function is  21.44267372098234
# Running Gradient Descent. Current cost function is  21.44262815945249
# Running Gradient Descent. Current cost function is  21.442583056894236
# Running Gradient Descent. Current cost function is  21.442538408108195
# Running Gradient Descent. Current cost function is  21.44249420796378
# Running Gradient Descent. Current cost function is  21.442450451398134
# Running Gradient Descent. Current cost function is  21.44240713341509
# Running Gradient Descent. Current cost function is  21.44236424908415
# Running Gradient Descent. Current cost function is  21.44232179353948
# Running Gradient Descent. Current cost function is  21.442279761978906
# Running Gradient Descent. Current cost function is  21.442238149662963
# Running Gradient Descent. Current cost function is  21.44219695191393
# Running Gradient Descent. Current cost function is  21.442156164114895
# Running Gradient Descent. Current cost function is  21.442115781708814
# Running Gradient Descent. Current cost function is  21.44207580019764
# Running Gradient Descent. Current cost function is  21.442036215141393
# Running Gradient Descent. Current cost function is  21.441997022157306
# Running Gradient Descent. Current cost function is  21.441958216918955
# Running Gradient Descent. Current cost function is  21.44191979515542
# Running Gradient Descent. Current cost function is  21.441881752650445
# Running Gradient Descent. Current cost function is  21.441844085241613
# Running Gradient Descent. Current cost function is  21.44180678881955
# Running Gradient Descent. Current cost function is  21.44176985932715
# Running Gradient Descent. Current cost function is  21.44173329275875
# Running Gradient Descent. Current cost function is  21.441697085159422
# Running Gradient Descent. Current cost function is  21.441661232624174
# Running Gradient Descent. Current cost function is  21.441625731297247
# Running Gradient Descent. Current cost function is  21.441590577371354
# Running Gradient Descent. Current cost function is  21.441555767086996
# Running Gradient Descent. Current cost function is  21.441521296731736
# Running Gradient Descent. Current cost function is  21.441487162639525
# Running Gradient Descent. Current cost function is  21.44145336119001
# Running Gradient Descent. Current cost function is  21.44141988880787
# Running Gradient Descent. Current cost function is  21.441386741962166
# Running Gradient Descent. Current cost function is  21.441353917165678
# Running Gradient Descent. Current cost function is  21.44132141097429
# Running Gradient Descent. Current cost function is  21.441289219986345
# Running Gradient Descent. Current cost function is  21.441257340842043
# Running Gradient Descent. Current cost function is  21.44122577022284
# Running Gradient Descent. Current cost function is  21.441194504850838
# Running Gradient Descent. Current cost function is  21.441163541488212
# Running Gradient Descent. Current cost function is  21.441132876936635
# Running Gradient Descent. Current cost function is  21.441102508036703
# Running Gradient Descent. Current cost function is  21.441072431667394
# Running Gradient Descent. Current cost function is  21.4410426447455
# Running Gradient Descent. Current cost function is  21.44101314422511
# Running Gradient Descent. Current cost function is  21.44098392709707
# Running Gradient Descent. Current cost function is  21.44095499038845
# Running Gradient Descent. Current cost function is  21.440926331162068
# Running Gradient Descent. Current cost function is  21.44089794651594
# Running Gradient Descent. Current cost function is  21.440869833582813
# Running Gradient Descent. Current cost function is  21.440841989529677
# Running Gradient Descent. Current cost function is  21.44081441155727
# Running Gradient Descent. Current cost function is  21.440787096899616
# Running Gradient Descent. Current cost function is  21.440760042823566
# Running Gradient Descent. Current cost function is  21.44073324662832
# Running Gradient Descent. Current cost function is  21.440706705645002
# Running Gradient Descent. Current cost function is  21.4406804172362
# Running Gradient Descent. Current cost function is  21.44065437879554
# Running Gradient Descent. Current cost function is  21.44062858774725
# Running Gradient Descent. Current cost function is  21.440603041545735
# Running Gradient Descent. Current cost function is  21.44057773767519
# Running Gradient Descent. Current cost function is  21.440552673649155
# Running Gradient Descent. Current cost function is  21.440527847010127
# Running Gradient Descent. Current cost function is  21.440503255329176
# Running Gradient Descent. Current cost function is  21.440478896205537
# Running Gradient Descent. Current cost function is  21.440454767266246
# Running Gradient Descent. Current cost function is  21.440430866165745
# Running Gradient Descent. Current cost function is  21.44040719058552
# Running Gradient Descent. Current cost function is  21.440383738233734
# Running Gradient Descent. Current cost function is  21.440360506844875
# Running Gradient Descent. Current cost function is  21.440337494179385
# Running Gradient Descent. Current cost function is  21.44031469802332
# Running Gradient Descent. Current cost function is  21.44029211618803
# Running Gradient Descent. Current cost function is  21.44026974650977
# Running Gradient Descent. Current cost function is  21.44024758684942
# Running Gradient Descent. Current cost function is  21.440225635092126
# Running Gradient Descent. Current cost function is  21.440203889146993
# Running Gradient Descent. Current cost function is  21.44018234694675
# Running Gradient Descent. Current cost function is  21.440161006447465
# Running Gradient Descent. Current cost function is  21.440139865628215
# Running Gradient Descent. Current cost function is  21.440118922490793
# Running Gradient Descent. Current cost function is  21.440098175059404
# Running Gradient Descent. Current cost function is  21.44007762138038
# Running Gradient Descent. Current cost function is  21.440057259521886
# Running Gradient Descent. Current cost function is  21.440037087573632
# Running Gradient Descent. Current cost function is  21.4400171036466
# Running Gradient Descent. Current cost function is  21.439997305872765
# Running Gradient Descent. Current cost function is  21.43997769240482
# Running Gradient Descent. Current cost function is  21.43995826141591
# Running Gradient Descent. Current cost function is  21.439939011099376
# Running Gradient Descent. Current cost function is  21.439919939668485
# Running Gradient Descent. Current cost function is  21.439901045356176
# Running Gradient Descent. Current cost function is  21.43988232641481
# Running Gradient Descent. Current cost function is  21.43986378111593
# Running Gradient Descent. Current cost function is  21.439845407749996
# Running Gradient Descent. Current cost function is  21.43982720462617
# Running Gradient Descent. Current cost function is  21.439809170072053
# Running Gradient Descent. Current cost function is  21.439791302433473
# Running Gradient Descent. Current cost function is  21.439773600074247
# Running Gradient Descent. Current cost function is  21.43975606137595
# Running Gradient Descent. Current cost function is  21.439738684737687
# Running Gradient Descent. Current cost function is  21.439721468575893
# Running Gradient Descent. Current cost function is  21.439704411324104
# Running Gradient Descent. Current cost function is  21.439687511432734
# Running Gradient Descent. Current cost function is  21.439670767368877
# ...
# Running Gradient Descent. Current cost function is  21.438605827533333
# Running Gradient Descent. Current cost function is  21.43859889506398
# Running Gradient Descent. Current cost function is  21.438592024499197
# Running Gradient Descent. Current cost function is  21.43858521527482
# Running Gradient Descent. Current cost function is  21.43857846683205
# Running Gradient Descent. Current cost function is  21.43857177861739
# Running Gradient Descent. Current cost function is  21.438565150082617
# Running Gradient Descent. Current cost function is  21.438558580684692
# Running Gradient Descent. Current cost function is  21.438552069885727
# Running Gradient Descent. Current cost function is  21.43854561715293
# Running Gradient Descent. Current cost function is  21.438539221958553
# Running Gradient Descent. Current cost function is  21.438532883779835
# Running Gradient Descent. Current cost function is  21.43852660209896
# Running Gradient Descent. Current cost function is  21.438520376402998
# Running Gradient Descent. Current cost function is  21.438514206183864
# Running Gradient Descent. Current cost function is  21.43850809093825
# Running Gradient Descent. Current cost function is  21.43850203016761
# Running Gradient Descent. Current cost function is  21.43849602337807
# Running Gradient Descent. Current cost function is  21.438490070080427
# Running Gradient Descent. Current cost function is  21.43848416979005
# Running Gradient Descent. Current cost function is  21.43847832202689
# Running Gradient Descent. Current cost function is  21.43847252631538
# Running Gradient Descent. Current cost function is  21.438466782184427
# Running Gradient Descent. Current cost function is  21.438461089167355
# Running Gradient Descent. Current cost function is  21.43845544680186
# Running Gradient Descent. Current cost function is  21.43844985462996
# Running Gradient Descent. Current cost function is  21.438444312197966
# Running Gradient Descent. Current cost function is  21.438438819056426
# Running Gradient Descent. Current cost function is  21.438433374760095
# Running Gradient Descent. Current cost function is  21.438427978867875
# Running Gradient Descent. Current cost function is  21.438422630942796
# Running Gradient Descent. Current cost function is  21.438417330551957
# Running Gradient Descent. Current cost function is  21.43841207726649
# Running Gradient Descent. Current cost function is  21.438406870661527
# Running Gradient Descent. Current cost function is  21.438401710316157
# Running Gradient Descent. Current cost function is  21.438396595813373
# Running Gradient Descent. Current cost function is  21.43839152674006
# Running Gradient Descent. Current cost function is  21.43838650268693
# Running Gradient Descent. Current cost function is  21.43838152324851
# Running Gradient Descent. Current cost function is  21.438376588023072
# Running Gradient Descent. Current cost function is  21.438371696612627
# Running Gradient Descent. Current cost function is  21.438366848622877
# Running Gradient Descent. Current cost function is  21.438362043663165
# Running Gradient Descent. Current cost function is  21.438357281346466
# Running Gradient Descent. Current cost function is  21.438352561289328
# Running Gradient Descent. Current cost function is  21.43834788311185
# Running Gradient Descent. Current cost function is  21.438343246437636
# Running Gradient Descent. Current cost function is  21.43833865089378
# Running Gradient Descent. Current cost function is  21.43833409611081
# Running Gradient Descent. Current cost function is  21.438329581722666
# Running Gradient Descent. Current cost function is  21.43832510736667
# Running Gradient Descent. Current cost function is  21.438320672683474
# Running Gradient Descent. Current cost function is  21.438316277317064
# Running Gradient Descent. Current cost function is  21.438311920914686
# Running Gradient Descent. Current cost function is  21.43830760312684
# Running Gradient Descent. Current cost function is  21.438303323607244
# Running Gradient Descent. Current cost function is  21.4382990820128
# Running Gradient Descent. Current cost function is  21.438294878003557
# Running Gradient Descent. Current cost function is  21.4382907112427
# Running Gradient Descent. Current cost function is  21.438286581396493
# Running Gradient Descent. Current cost function is  21.43828248813428
# Running Gradient Descent. Current cost function is  21.43827843112842
# Running Gradient Descent. Current cost function is  21.43827441005429
# Running Gradient Descent. Current cost function is  21.43827042459024
# Running Gradient Descent. Current cost function is  21.438266474417564
# Running Gradient Descent. Current cost function is  21.438262559220476
# Running Gradient Descent. Current cost function is  21.43825867868608
# Running Gradient Descent. Current cost function is  21.438254832504345
# Running Gradient Descent. Current cost function is  21.43825102036807
# Running Gradient Descent. Current cost function is  21.438247241972874
# Running Gradient Descent. Current cost function is  21.438243497017147
# Running Gradient Descent. Current cost function is  21.438239785202033
# Running Gradient Descent. Current cost function is  21.43823610623141
# Running Gradient Descent. Current cost function is  21.43823245981186
# Running Gradient Descent. Current cost function is  21.438228845652635
# Running Gradient Descent. Current cost function is  21.43822526346564
# Running Gradient Descent. Current cost function is  21.43822171296541
# Running Gradient Descent. Current cost function is  21.43821819386908
# Running Gradient Descent. Current cost function is  21.438214705896357
# Running Gradient Descent. Current cost function is  21.438211248769505
# Running Gradient Descent. Current cost function is  21.43820782221331
# Running Gradient Descent. Current cost function is  21.438204425955067
# Running Gradient Descent. Current cost function is  21.43820105972455
# Running Gradient Descent. Current cost function is  21.43819772325398
# Running Gradient Descent. Current cost function is  21.438194416278034
# Running Gradient Descent. Current cost function is  21.43819113853377
# Running Gradient Descent. Current cost function is  21.438187889760655
# Running Gradient Descent. Current cost function is  21.43818466970051
# Running Gradient Descent. Current cost function is  21.43818147809751
# Running Gradient Descent. Current cost function is  21.438178314698128
# Running Gradient Descent. Current cost function is  21.438175179251164
# Running Gradient Descent. Current cost function is  21.438172071507676
# Running Gradient Descent. Current cost function is  21.438168991220984
# Running Gradient Descent. Current cost function is  21.43816593814664
# Running Gradient Descent. Current cost function is  21.438162912042408
# Running Gradient Descent. Current cost function is  21.438159912668254
# Running Gradient Descent. Current cost function is  21.438156939786307
# Running Gradient Descent. Current cost function is  21.438153993160846
# Running Gradient Descent. Current cost function is  21.438151072558288
# Running Gradient Descent. Current cost function is  21.43814817774716
# Running Gradient Descent. Current cost function is  21.43814530849808
# Running Gradient Descent. Current cost function is  21.438142464583738
# Running Gradient Descent. Current cost function is  21.438139645778875
# Running Gradient Descent. Current cost function is  21.43813685186027
# Running Gradient Descent. Current cost function is  21.43813408260672
# Running Gradient Descent. Current cost function is  21.438131337799003
# Running Gradient Descent. Current cost function is  21.438128617219892
# Running Gradient Descent. Current cost function is  21.438125920654105
# Running Gradient Descent. Current cost function is  21.438123247888313
# Running Gradient Descent. Current cost function is  21.4381205987111
# Running Gradient Descent. Current cost function is  21.438117972912966
# Running Gradient Descent. Current cost function is  21.43811537028628
# Running Gradient Descent. Current cost function is  21.438112790625297
# Running Gradient Descent. Current cost function is  21.438110233726118
# Running Gradient Descent. Current cost function is  21.43810769938668
# Running Gradient Descent. Current cost function is  21.43810518740674
# Running Gradient Descent. Current cost function is  21.43810269758785
# Running Gradient Descent. Current cost function is  21.438100229733354
# Running Gradient Descent. Current cost function is  21.438097783648363
# Running Gradient Descent. Current cost function is  21.43809535913973
# Running Gradient Descent. Current cost function is  21.43809295601606
# Running Gradient Descent. Current cost function is  21.438090574087663
# Running Gradient Descent. Current cost function is  21.438088213166562
# Running Gradient Descent. Current cost function is  21.438085873066463
# Running Gradient Descent. Current cost function is  21.438083553602745
# Running Gradient Descent. Current cost function is  21.438081254592444
# Running Gradient Descent. Current cost function is  21.43807897585424
# Running Gradient Descent. Current cost function is  21.438076717208435
# Running Gradient Descent. Current cost function is  21.43807447847695
# Running Gradient Descent. Current cost function is  21.438072259483295
# Running Gradient Descent. Current cost function is  21.438070060052567
# Running Gradient Descent. Current cost function is  21.438067880011427
# Running Gradient Descent. Current cost function is  21.438065719188092
# Running Gradient Descent. Current cost function is  21.43806357741232
# Running Gradient Descent. Current cost function is  21.438061454515385
# Running Gradient Descent. Current cost function is  21.43805935033008
# Running Gradient Descent. Current cost function is  21.438057264690695
# Running Gradient Descent. Current cost function is  21.438055197432995
# Running Gradient Descent. Current cost function is  21.438053148394225
# Running Gradient Descent. Current cost function is  21.438051117413078
# Running Gradient Descent. Current cost function is  21.438049104329696
# Running Gradient Descent. Current cost function is  21.438047108985646
# Running Gradient Descent. Current cost function is  21.438045131223916
# Running Gradient Descent. Current cost function is  21.438043170888893
# Running Gradient Descent. Current cost function is  21.438041227826353
# Running Gradient Descent. Current cost function is  21.438039301883464
# Running Gradient Descent. Current cost function is  21.43803739290874
# Running Gradient Descent. Current cost function is  21.438035500752065
# Running Gradient Descent. Current cost function is  21.438033625264648
# Running Gradient Descent. Current cost function is  21.438031766299044
# Running Gradient Descent. Current cost function is  21.43802992370911
# Running Gradient Descent. Current cost function is  21.43802809735001
# Running Gradient Descent. Current cost function is  21.43802628707821
# Running Gradient Descent. Current cost function is  21.438024492751445
# Running Gradient Descent. Current cost function is  21.438022714228726
# Running Gradient Descent. Current cost function is  21.438020951370323
# Running Gradient Descent. Current cost function is  21.43801920403774
# Running Gradient Descent. Current cost function is  21.438017472093733
# Running Gradient Descent. Current cost function is  21.43801575540227
# Running Gradient Descent. Current cost function is  21.43801405382853
# Running Gradient Descent. Current cost function is  21.43801236723891
# Running Gradient Descent. Current cost function is  21.43801069550097
# Running Gradient Descent. Current cost function is  21.43800903848348
# Running Gradient Descent. Current cost function is  21.438007396056356
# Running Gradient Descent. Current cost function is  21.438005768090687
# Running Gradient Descent. Current cost function is  21.438004154458696
# Running Gradient Descent. Current cost function is  21.43800255503376
# Running Gradient Descent. Current cost function is  21.438000969690368
# Running Gradient Descent. Current cost function is  21.43799939830414
# Running Gradient Descent. Current cost function is  21.437997840751787
# Running Gradient Descent. Current cost function is  21.437996296911134
# Running Gradient Descent. Current cost function is  21.437994766661085
# Running Gradient Descent. Current cost function is  21.437993249881615
# Running Gradient Descent. Current cost function is  21.437991746453775
# Running Gradient Descent. Current cost function is  21.437990256259674
# Running Gradient Descent. Current cost function is  21.43798877918246
# Running Gradient Descent. Current cost function is  21.437987315106337
# Running Gradient Descent. Current cost function is  21.43798586391652
# Running Gradient Descent. Current cost function is  21.437984425499252
# Running Gradient Descent. Current cost function is  21.43798299974179
# Running Gradient Descent. Current cost function is  21.43798158653239
# Running Gradient Descent. Current cost function is  21.4379801857603
# Running Gradient Descent. Current cost function is  21.43797879731575
# Running Gradient Descent. Current cost function is  21.43797742108995
# Running Gradient Descent. Current cost function is  21.437976056975074
# Running Gradient Descent. Current cost function is  21.43797470486425
# Running Gradient Descent. Current cost function is  21.43797336465156
# Running Gradient Descent. Current cost function is  21.437972036232022
# Running Gradient Descent. Current cost function is  21.437970719501592
# Running Gradient Descent. Current cost function is  21.43796941435714
# Running Gradient Descent. Current cost function is  21.437968120696464
# Running Gradient Descent. Current cost function is  21.437966838418255
# Running Gradient Descent. Current cost function is  21.43796556742211
# Running Gradient Descent. Current cost function is  21.43796430760852
# Running Gradient Descent. Current cost function is  21.437963058878857
# Running Gradient Descent. Current cost function is  21.437961821135357
# Running Gradient Descent. Current cost function is  21.437960594281137
# Running Gradient Descent. Current cost function is  21.437959378220167
# Running Gradient Descent. Current cost function is  21.43795817285727
# Running Gradient Descent. Current cost function is  21.43795697809811
# Running Gradient Descent. Current cost function is  21.43795579384919
# Running Gradient Descent. Current cost function is  21.43795462001784
# Running Gradient Descent. Current cost function is  21.437953456512215
# Running Gradient Descent. Current cost function is  21.43795230324128
# Running Gradient Descent. Current cost function is  21.4379511601148
# Running Gradient Descent. Current cost function is  21.43795002704336
# Running Gradient Descent. Current cost function is  21.437948903938317
# Running Gradient Descent. Current cost function is  21.43794779071182
# Running Gradient Descent. Current cost function is  21.4379466872768
# Running Gradient Descent. Current cost function is  21.437945593546953
# Running Gradient Descent. Current cost function is  21.43794450943674
# Running Gradient Descent. Current cost function is  21.43794343486139
# Running Gradient Descent. Current cost function is  21.437942369736863
# Running Gradient Descent. Current cost function is  21.43794131397988
# Running Gradient Descent. Current cost function is  21.437940267507898
# Running Gradient Descent. Current cost function is  21.43793923023909
# Running Gradient Descent. Current cost function is  21.437938202092365
# Running Gradient Descent. Current cost function is  21.437937182987355
# Running Gradient Descent. Current cost function is  21.437936172844385
# Running Gradient Descent. Current cost function is  21.437935171584506
# Running Gradient Descent. Current cost function is  21.437934179129453
# Running Gradient Descent. Current cost function is  21.437933195401655
# Running Gradient Descent. Current cost function is  21.437932220324235
# Running Gradient Descent. Current cost function is  21.437931253820988
# Running Gradient Descent. Current cost function is  21.437930295816386
# Running Gradient Descent. Current cost function is  21.437929346235567

# %%
# Now, lets see our trained weights
print('Our learned value of theta: ',theta.ravel())
# Out:
# Our learned value of theta:  [340397.96353532 108742.65627238  -5873.22993383]

# %% [markdown]
# Lets visualize how or error reduced during the iteration. This is the power of gradient descent.

# %%
plt.plot(cost_values)
plt.ylabel('Cost J')
plt.xlabel('Iterations');

# %% [markdown]
# Notice that at the `400th iteration`, the model doesnt really change anymore. You should actually stop the iteration at that time and save cost of processing

# %% [markdown]
# ## Predict
#
# Lets write a predict function that takes in the input features and produces an estimate price for the type of house desired

# %%
def predict(theta, mean, std):
    input_size = float(input("Input the size (square feet) of house you want: "))
    input_bedrooms = float(input("Input the number of bedrooms you desire: "))
    print("\nCalculating... ... ... ... ... ...\n")
    input_vec = np.array([[1, input_size, input_bedrooms]])
    
    input_norm = np.ones(input_vec.shape)
    input_norm.dtype = np.float
    
    input_norm[:, 1:] = np.divide((input_vec[:, 1:] - mean), std)
    
    price = input_norm @ theta
    print("For a house of size ", input_size, "sqft, with ", input_bedrooms, "rooms, \nThe price estimate is N", price[0][0])

# %%
predict(theta, mean, standard_deviation)
# Out:
# Input the size (square feet) of house you want: 8966
# Input the number of bedrooms you desire: 4
#
# Calculating... ... ... ... ... ...
#
# For a house of size  8966.0 sqft, with  4.0 rooms,
# The price estimate is N 1297324.0815724498

# %% [markdown]
# ### Learning Rates

# %% [markdown]
# But what ius the effect of varying learning rates in the optimization of our weights?
# Below, we will plot the effect of different learning on the optimization of theta.
#
# Study the code for the next 5 mins...

# %%
# Choose some alpha value
alphas = [1,0,0.1,0.01]

def update_weight_r(h, theta, x, alpha):
    m = x[:,0].size
    theta = theta - alpha * (1/m * (x.T @ (h - y)))
    return theta

def cost_r(x):
    J = []
    theta = [[0],[0],[0]]
    iteration = 10
    for i in alphas:
        alpha = i
        m = x[:,0].size
        J_alpha = []
        for i in range(iteration):
            h = x @ theta
            theta = update_weight_r(h, theta, x, alpha)
            cost = (1/2*m) * np.sum(np.square(h - y))
            J_alpha.append(cost)
        # reset theta to zero
        theta = [[0],[0],[0]]
        J.append(J_alpha)
    return J

# %%
# Lets pass in the value of x into our function defined above 
cost_alpha = cost_r(x)

plt.figure()
plt.subplot(2,2,1)
plt.plot(cost_alpha[0])
plt.title('lr= 1')

plt.subplot(2,2,2)
plt.plot(cost_alpha[1])
plt.title('lr= 0')

plt.subplot(2,2,3)
plt.plot(cost_alpha[2])
plt.title('lr= 0.1')

plt.subplot(2,2,4)
plt.plot(cost_alpha[3])
plt.title('lr= 0.01')
# Out:
# Text(0.5, 1.0, 'lr= 0.01')

# %% [markdown]
# **Class Discussion:** What did you notice in this plots

# %% [markdown]
# ## Normal Equation (Analytical Method)

# %% [markdown]
# $$\theta = (X^TX)^{-1}X^T\vec{y}$$
# Using this formula does not require any feature scaling, and you will get an exact solution in one calculation: there is no \loop until convergence" like in gradient descent.
#
# Complete the code in normaleqn.py to use the formula above to calcu- late $\theta$. Remember that while you don't need to scale your features, we still need to add a column of 1's to the X matrix to have an intercept term

# %%
# lets define the formula in a function
def normalEqn(X,y):
    return np.dot((np.linalg.inv(np.dot(X.T,X))),np.dot(X.T,y))

# %%
# Lets pass in our inout values the have not been normalized
x_non_norm = np.concatenate((np.ones((x_data[:,0].size, 1)), x_data), axis=1) 

theta_analytical = normalEqn(x_non_norm, y)

# Display normal equation's result
print ('Theta computed from the normal equations:')
print (' %s \n' % theta_analytical)
# Out:
# Theta computed from the normal equations:
#  [[89597.9095428 ]
#  [  139.21067402]
#  [-8738.01911233]]

# %%
#Predict
def predict_analytical(theta):
    input_size = float(input("Input the size (square feet) of house you want: "))
    input_bedrooms = float(input("Input the number of bedrooms you desire: "))
    print("\nCalculating... ... ... ... ... ...\n")
    input_vec = np.array([[1, input_size, input_bedrooms]])
    
    
    price = input_vec @ theta
    print("For a house of size ", input_size, "sqft, with ", input_bedrooms, "rooms, \nThe price estimate is N", price[0][0])

# %%
predict_analytical(theta_analytical)
# Out:
# Input the size (square feet) of house you want: 1650
# Input the number of bedrooms you desire: 4
#
# Calculating... ... ... ... ... ...
#
# For a house of size  1650.0 sqft, with  4.0 rooms,
# The price estimate is N 284343.4452225697

# %% [markdown]
# ### Assignment:
#
# 1. Use `scikit-learn` to develop a linear regression model using the same dataset in this practice and compare result.
# 2. Explore the internet for an multivariant dataset and use this algorithim to train a linear regression model. Use `scikit-learn` too
#
# Assignment is due for submission on `05/04/2019`.
#
# Summission link will be posted on the `WhatsApp Class Group`
